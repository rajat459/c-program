# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat459/c-program/blob/main/advancequestion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1=[1,6,3,4,5]
is_decreasing=0
is_increasing=0
for i in range(len(list1)-1):
  if list1[i]>list1[i+1]:
    is_decreasing=1

for i in range(len(list1)-1):
  if list1[i]<list1[i+1]:
    is_increasing=1

if (is_increasing==1and is_decreasing==1):
  print('monotonic')
else:
  print(' non monotonic')
# Out:
# monotonic

# %%
n=int(input('ENTER S NUMBER'))
temp=n
count=0
sum=0
rem=0
while(n>0):
    n= n//10
    count+=1
n=temp
while(n>0):
    rem=n%10
    sum=sum+rem**count
    n= n//10
    count-=1
if(temp==sum):
    print('yes')
else:
    print('no')

print(count)
# Out:
# ENTER S NUMBER12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-2572807f6df2> in <cell line: 4>()
#       2 temp=1
#       3 count=0
# ----> 4 while(n>0):
#       5     r=n%10
#       6     count+=1
#
# KeyboardInterrupt:

# %%
n=int(input('enter'))
temp=n
rem=0
sum=0
while(n>0):
    rem=n%10
    sum=sum+rem
    n=n//10
if(n//sum==0):
    print('yes')
else:
    print("no")
